# %% [markdown]
# # JobBERT Fairness Analysis
#
# ### Evaluating Demographic Bias in CV–Job Matching Using Synthetic Data
#
# This notebook explores how the **TechWolf/JobBERT-v2** sentence-embedding model behaves when matching synthetic CVs to job postings. The goal is to understand whether certain demographic groups (e.g., gender and ethnicity) receive systematically different similarity scores for the *same roles* and *same seniority levels*.
#
# We analyze the model’s outputs along two main dimensions:
#
# 1. **Eligibility Analysis:**
#    How strongly each demographic group is matched to job roles overall.
#    Higher similarity values indicate the model perceives a CV as more suitable for a given job posting.
#
# 2. **Seniority Progression Analysis:**
#    How similarity changes as job seniority increases (Junior → Mid → Senior → Lead).
#    This highlights whether a group is implicitly “lifted” or “pushed downward” as job levels rise.
#
#
# The notebook proceeds by computing similarity matrices, aggregating mean scores, analyzing seniority deltas, and visualizing all results in multiple formats (bar charts, heatmaps, grouped plots).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cv_job_similarity.csv")
df.head()
# Out:
#   cv_id          name gender              ethnicity               role job_id  \
# 0  CV_0  Ahmed Hassan   male  arabic_middle_eastern  Software Engineer  JOB_0
# 1  CV_0  Ahmed Hassan   male  arabic_middle_eastern  Software Engineer  JOB_1
# 2  CV_0  Ahmed Hassan   male  arabic_middle_eastern  Software Engineer  JOB_2
# 3  CV_0  Ahmed Hassan   male  arabic_middle_eastern  Software Engineer  JOB_3
# 4  CV_0  Ahmed Hassan   male  arabic_middle_eastern  Software Engineer  JOB_4
#
#             job_role job_domain job_level  \
# 0  Software Engineer       tech    Junior
# 1  Software Engineer       tech    Junior
# 2  Software Engineer       tech       Mid
# 3  Software Engineer       tech       Mid
# 4  Software Engineer       tech    Senior
#
#                                             job_text  similarity
# 0  Hiring a Junior Software Engineer to implement...    0.549975
# 1  Junior Software Engineer role focused on contr...    0.595809
# 2  Seeking a Software Engineer to design APIs, ma...    0.661968
# 3  Software Engineer needed to work on applicatio...    0.619108
# 4  Senior Software Engineer role involving owners...    0.582217

# %% [markdown]
# ---

# %% [markdown]
# ## 1. GENDER ANALYSIS

# %%
GENDER_COLORS = {
    "male":   "#1f77b4",
    "female": "#ff7f0e",
    "other":  "#2ca02c"
}

# %% [markdown]
# ### 1.1 Gender Bias Analysis (Eligibility)

# %%
# Mean similarity by gender for each role (all levels combined)
gender_role_stats = (
    df.groupby(["role", "gender"])["similarity"]
      .mean()
      .unstack()
)

gender_role_stats
# Out:
# gender                     female      male
# role
# Construction Supervisor  0.708928  0.711426
# Data Scientist           0.627379  0.625474
# Electrician              0.639776  0.641041
# Financial Analyst        0.618984  0.614030
# Graphic Designer         0.653994  0.639747
# High School Teacher      0.752458  0.746697
# Marketing Manager        0.629342  0.613186
# Mechanical Technician    0.639945  0.642328
# Pediatric Nurse          0.642355  0.643274
# Pharmacist               0.498810  0.495728
# Policy Analyst           0.696257  0.703160
# Product Manager          0.642063  0.644707
# Project Manager          0.607826  0.602130
# Registered Nurse (ICU)   0.616957  0.612602
# Research Assistant       0.666644  0.653429
# Social Worker            0.610674  0.616091
# Software Engineer        0.556653  0.546958
# University Lecturer      0.650338  0.654078

# %%
plt.figure(figsize=(10,5))
sns.barplot(
    data=df, 
    x="role", 
    y="similarity", 
    hue="gender", 
    ci="sd",
    palette=GENDER_COLORS
)
plt.title("Gender Differences in Eligibility (All Levels Combined)")
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\IuG_Lap1\AppData\Local\Temp\ipykernel_34184\1105100597.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ---

# %% [markdown]
# ### 1.2 Gender Bias in Seniority Levels

# %% [markdown]
# #### 2.2.1 Group-Level Similarity Analysis (Mean Scores)

# %%
# Pivot CV–job similarities by seniority level
pivot = df.pivot_table(
    index=["cv_id", "gender", "ethnicity", "role"],
    columns="job_level",
    values="similarity"
)

pivot = pivot.reset_index()
pivot.head()
# Out:
# job_level    cv_id  gender                ethnicity                 role  \
# 0             CV_0    male    arabic_middle_eastern    Software Engineer
# 1             CV_1    male    arabic_middle_eastern       Data Scientist
# 2            CV_10    male    arabic_middle_eastern  University Lecturer
# 3           CV_100  female    arabic_middle_eastern  University Lecturer
# 4          CV_1000  female  hispanic_latin_american  University Lecturer
#
# job_level    Junior      Lead       Mid    Senior
# 0          0.572892  0.499737  0.640538  0.568384
# 1          0.598619  0.583439  0.638846  0.671058
# 2          0.591379  0.705591  0.590275  0.720635
# 3          0.608812  0.699538  0.592210  0.709816
# 4          0.597114  0.665541  0.585172  0.698315

# %%
gender_seniority_means = (
    pivot.groupby("gender")[["Junior", "Mid", "Senior", "Lead"]]
         .mean()
)

gender_seniority_means
# Out:
# job_level    Junior       Mid    Senior      Lead
# gender
# female     0.619830  0.648961  0.661735  0.616004
# male       0.608082  0.644185  0.665422  0.616997

# %%
colors = [GENDER_COLORS[g] for g in gender_seniority_means.index]

plt.figure(figsize=(8,5))
ax = gender_seniority_means.T.plot(kind="bar", color=colors)

plt.title("Gender Difference Across Seniority Levels")
plt.ylabel("Mean Similarity")
plt.xlabel("Job Level")
plt.xticks(rotation=0)

# Move legend outside on the right
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc="upper left")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.heatmap(
    gender_seniority_means,
    annot=True,
    cmap="coolwarm",
    center=gender_seniority_means.values.mean(),
    linewidths=.5
)

plt.title("Gender Differences Across Seniority Levels")
plt.xlabel("Seniority Level")
plt.ylabel("Gender")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### 2.2.2 Seniority Delta Analysis (Δ from Junior Level)

# %% [markdown]
# ##### Understanding the Seniority Delta Table
#
# The seniority delta table shows how a candidate’s similarity score changes as job seniority increases. Instead of looking at raw similarity values, we compute how much each seniority level deviates from the **Junior** level.
#
# For each CV, we calculate:
#
# $$
# \Delta_{\text{Level}} = \text{similarity(Level)} - \text{similarity(Junior)}
# $$
#
# This gives us a *trajectory* of how the model's perception changes across seniority levels.
#
# Using Junior as a baseline makes it easy to interpret how each group (e.g., gender or ethnicity) shifts as seniority increases.
#
# In other words: **_These numbers show how the model’s confidence changes when moving from Junior roles to more senior ones. Positive values mean the model sees that gender as increasingly suitable for higher levels, while negative values mean the opposite_**
#
# ---
#
# ##### How to read the deltas
#
# * **Positive delta**
#   The model thinks the candidate fits this seniority level *more* than the Junior level.
#
# * **Negative delta**
#   The model finds the candidate *less suitable* for that seniority level compared to Junior.
#
# * **Delta = 0**
#   No change in perceived suitability.

# %%
levels = ["Junior", "Mid", "Senior", "Lead"]

for lvl in levels:
    if lvl != "Junior":
        pivot[f"delta_{lvl}_vs_Junior"] = pivot[lvl] - pivot["Junior"]

pivot.head()
# Out:
# job_level    cv_id  gender                ethnicity                 role  \
# 0             CV_0    male    arabic_middle_eastern    Software Engineer
# 1             CV_1    male    arabic_middle_eastern       Data Scientist
# 2            CV_10    male    arabic_middle_eastern  University Lecturer
# 3           CV_100  female    arabic_middle_eastern  University Lecturer
# 4          CV_1000  female  hispanic_latin_american  University Lecturer
#
# job_level    Junior      Lead       Mid    Senior  delta_Mid_vs_Junior  \
# 0          0.572892  0.499737  0.640538  0.568384             0.067646
# 1          0.598619  0.583439  0.638846  0.671058             0.040227
# 2          0.591379  0.705591  0.590275  0.720635            -0.001105
# 3          0.608812  0.699538  0.592210  0.709816            -0.016602
# 4          0.597114  0.665541  0.585172  0.698315            -0.011942
#
# job_level  delta_Senior_vs_Junior  delta_Lead_vs_Junior
# 0                       -0.004508             -0.073155
# 1                        0.072440             -0.015179
# 2                        0.129256              0.114212
# 3                        0.101004              0.090726
# 4                        0.101201              0.068427

# %%
gender_delta_stats = (
    pivot.groupby("gender")[
        [f"delta_{lvl}_vs_Junior" for lvl in levels if lvl != "Junior"]
    ].mean()
)

plt.figure(figsize=(8,5))
sns.heatmap(
    gender_delta_stats,
    annot=True,
    cmap="coolwarm",
    linewidths=.5
)
plt.title("Gender Differences in Seniority Deltas (vs Junior)")
plt.ylabel("Gender")
plt.xlabel("Job Level")
plt.show()

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 2. ETHNICITY ANALYSIS
#
# ---

# %%
ETHNICITY_COLORS = {
    "arabic_middle_eastern": "#1f77b4",
    "western_european": "#ff7f0e",
    "south_asian": "#2ca02c",
    "east_asian": "#d62728",
    "african": "#1E352F",
    "hispanic_latin_american": "#941C2F",
    "eastern_european_slavic": "#C1CFDA",
    "southeast_asian": "#7A89C2",
}

# %% [markdown]
# ### 2.1 Ethnicity Bias (Eligibility)

# %%
eth_role_stats = (
    df.groupby(["role", "ethnicity"])["similarity"]
      .mean()
      .unstack()
)

eth_role_stats
# Out:
# ethnicity                 african  arabic_middle_eastern  east_asian  \
# role
# Construction Supervisor  0.730254               0.717532    0.704268
# Data Scientist           0.630402               0.615788    0.618286
# Electrician              0.653004               0.638623    0.630338
# Financial Analyst        0.615936               0.621864    0.610211
# Graphic Designer         0.660246               0.636261    0.647964
# High School Teacher      0.767102               0.745850    0.738221
# Marketing Manager        0.638288               0.609753    0.606732
# Mechanical Technician    0.651489               0.634869    0.638900
# Pediatric Nurse          0.647666               0.639216    0.651311
# Pharmacist               0.503379               0.489798    0.475115
# Policy Analyst           0.702032               0.697097    0.702987
# Product Manager          0.671567               0.637129    0.643999
# Project Manager          0.603050               0.614240    0.587344
# Registered Nurse (ICU)   0.618037               0.619174    0.612285
# Research Assistant       0.669425               0.661360    0.638829
# Social Worker            0.619214               0.606430    0.615411
# Software Engineer        0.557971               0.572182    0.542674
# University Lecturer      0.660590               0.656970    0.650341
#
# ethnicity                eastern_european_slavic  hispanic_latin_american  \
# role
# Construction Supervisor                 0.686597                 0.709966
# Data Scientist                          0.642252                 0.620566
# Electrician                             0.635865                 0.633534
# Financial Analyst                       0.616247                 0.613701
# Graphic Designer                        0.631494                 0.620105
# High School Teacher                     0.742388                 0.748366
# Marketing Manager                       0.614884                 0.620241
# Mechanical Technician                   0.633508                 0.632513
# Pediatric Nurse                         0.643411                 0.630682
# Pharmacist                              0.500523                 0.496854
# Policy Analyst                          0.694597                 0.687927
# Product Manager                         0.628369                 0.626217
# Project Manager                         0.596303                 0.603648
# Registered Nurse (ICU)                  0.613231                 0.607225
# Research Assistant                      0.656534                 0.673824
# Social Worker                           0.603383                 0.606960
# Software Engineer                       0.578341                 0.520209
# University Lecturer                     0.647736                 0.635254
#
# ethnicity                south_asian  southeast_asian  western_european
# role
# Construction Supervisor     0.710615         0.705634          0.716550
# Data Scientist              0.626713         0.618507          0.638897
# Electrician                 0.635970         0.639173          0.656760
# Financial Analyst           0.605997         0.619255          0.628847
# Graphic Designer            0.658893         0.636808          0.683193
# High School Teacher         0.733794         0.744885          0.776017
# Marketing Manager           0.608165         0.622619          0.649433
# Mechanical Technician       0.643123         0.652570          0.642118
# Pediatric Nurse             0.627734         0.641509          0.660983
# Pharmacist                  0.492780         0.518423          0.501282
# Policy Analyst              0.696059         0.697803          0.719168
# Product Manager             0.640754         0.655793          0.643252
# Project Manager             0.598709         0.610604          0.625925
# Registered Nurse (ICU)      0.606993         0.621268          0.620026
# Research Assistant          0.651993         0.653898          0.674431
# Social Worker               0.612080         0.614251          0.629333
# Software Engineer           0.532922         0.535245          0.574899
# University Lecturer         0.639706         0.653748          0.673321

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# mean similarity per (role, ethnicity)
role_eth_means = (
    df.groupby(["role", "ethnicity"])["similarity"]
      .mean()
      .unstack()      # rows = roles, columns = ethnicities
)

plt.figure(figsize=(14, 6))
sns.heatmap(
    role_eth_means,
    cmap="coolwarm",
    annot=False,          # set True if you want numbers on cells
    center=role_eth_means.values.mean(),
    linewidths=0.5
)
plt.title("Mean Similarity by Role and Ethnicity")
plt.xlabel("Ethnicity")
plt.ylabel("Role")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### 2.2 Ethnicity Bias in Seniority Levels

# %% [markdown]
# #### 2.2.1 Group-Level Similarity Analysis (Mean Scores)

# %%
pivot = df.pivot_table(
    index=["cv_id", "gender", "ethnicity", "role"],
    columns="job_level",
    values="similarity"
).reset_index()

pivot.head()
# Out:
# job_level    cv_id  gender                ethnicity                 role  \
# 0             CV_0    male    arabic_middle_eastern    Software Engineer
# 1             CV_1    male    arabic_middle_eastern       Data Scientist
# 2            CV_10    male    arabic_middle_eastern  University Lecturer
# 3           CV_100  female    arabic_middle_eastern  University Lecturer
# 4          CV_1000  female  hispanic_latin_american  University Lecturer
#
# job_level    Junior      Lead       Mid    Senior
# 0          0.572892  0.499737  0.640538  0.568384
# 1          0.598619  0.583439  0.638846  0.671058
# 2          0.591379  0.705591  0.590275  0.720635
# 3          0.608812  0.699538  0.592210  0.709816
# 4          0.597114  0.665541  0.585172  0.698315

# %%
eth_seniority_means = (
    pivot.groupby("ethnicity")[["Junior", "Mid", "Senior", "Lead"]]
         .mean()
)

eth_seniority_means
# Out:
# job_level                  Junior       Mid    Senior      Lead
# ethnicity
# african                  0.623431  0.655248  0.672779  0.626242
# arabic_middle_eastern    0.608140  0.642650  0.665988  0.619697
# east_asian               0.609695  0.642012  0.657630  0.605154
# eastern_european_slavic  0.610130  0.640328  0.663526  0.611719
# hispanic_latin_american  0.613103  0.640852  0.650066  0.604376
# south_asian              0.603118  0.641331  0.658952  0.612821
# southeast_asian          0.612538  0.649092  0.662460  0.618574
# western_european         0.631490  0.661072  0.677225  0.633421

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
df_plot = eth_seniority_means.T  # shape: levels × ethnicities
levels = df_plot.index
ethnicities = df_plot.columns
n_levels = len(levels)
n_groups = len(ethnicities)

# Bar settings
bar_width = 0.05        # make bars wide
group_spacing = 0.75    # spacing between seniority groups

# Compute positions
x = np.arange(n_levels) * group_spacing

plt.figure(figsize=(12,6))

for i, eth in enumerate(ethnicities):
    plt.bar(
        x + i * bar_width,
        df_plot[eth],
        width=bar_width,
        label=eth,
        color=ETHNICITY_COLORS.get(eth, None)
    )

plt.xticks(x + (n_groups-1)*bar_width/2, levels)
plt.ylabel("Mean Similarity")
plt.xlabel("Job Level")
plt.title("Ethnicity Differences Across Seniority Levels")

plt.legend(title="Ethnicity", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.heatmap(
    eth_seniority_means,
    annot=True,
    cmap="coolwarm",
    center=eth_seniority_means.values.mean(),
    linewidths=.5
)

plt.title("Ethnicity Differences Across Seniority Levels")
plt.xlabel("Seniority Level")
plt.ylabel("Ethnicity")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### 2.2.2 Seniority Delta Analysis (Δ from Junior Level)

# %%
levels = ["Junior", "Mid", "Senior", "Lead"]

for lvl in levels:
    if lvl != "Junior":
        pivot[f"delta_{lvl}_vs_Junior"] = pivot[lvl] - pivot["Junior"]

pivot.head()
# Out:
# job_level    cv_id  gender                ethnicity                 role  \
# 0             CV_0    male    arabic_middle_eastern    Software Engineer
# 1             CV_1    male    arabic_middle_eastern       Data Scientist
# 2            CV_10    male    arabic_middle_eastern  University Lecturer
# 3           CV_100  female    arabic_middle_eastern  University Lecturer
# 4          CV_1000  female  hispanic_latin_american  University Lecturer
#
# job_level    Junior      Lead       Mid    Senior  delta_Mid_vs_Junior  \
# 0          0.572892  0.499737  0.640538  0.568384             0.067646
# 1          0.598619  0.583439  0.638846  0.671058             0.040227
# 2          0.591379  0.705591  0.590275  0.720635            -0.001105
# 3          0.608812  0.699538  0.592210  0.709816            -0.016602
# 4          0.597114  0.665541  0.585172  0.698315            -0.011942
#
# job_level  delta_Senior_vs_Junior  delta_Lead_vs_Junior
# 0                       -0.004508             -0.073155
# 1                        0.072440             -0.015179
# 2                        0.129256              0.114212
# 3                        0.101004              0.090726
# 4                        0.101201              0.068427

# %%
eth_delta_stats = (
    pivot.groupby("ethnicity")[
        [f"delta_{lvl}_vs_Junior" for lvl in levels if lvl != "Junior"]
    ].mean()
)

plt.figure(figsize=(8,5))
sns.heatmap(
    eth_delta_stats,
    annot=True,
    cmap="coolwarm",
    center=0,
    linewidths=.5
)

plt.title("Ethnicity Differences in Seniority Deltas (vs Junior)")
plt.ylabel("Ethnicity")
plt.xlabel("Job Level")
plt.tight_layout()
plt.show()
